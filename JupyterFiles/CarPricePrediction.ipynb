# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
car = pd.read_csv(r'C:\Users\Sourasish\Desktop\CarPrice_Assignment.csv')

# %%
car.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
car.drop(['car_ID','CarName'], axis = 1, inplace = True)

# %%
car['fueltype']=car['fueltype'].astype('category')
car['fueltype']=car['fueltype'].cat.codes
car=pd.get_dummies(car, columns=['fueltype'])

# %%
car['aspiration']=car['aspiration'].astype('category')
car['aspiration']=car['aspiration'].cat.codes
car=pd.get_dummies(car, columns=['aspiration'])

# %%
car['doornumber']=car['doornumber'].astype('category')
car['doornumber']=car['doornumber'].cat.codes
car=pd.get_dummies(car, columns=['doornumber'])

# %%
car['carbody']=car['carbody'].astype('category')
car['carbody']=car['carbody'].cat.codes
car=pd.get_dummies(car, columns=['carbody'])

# %%
car['drivewheel']=car['drivewheel'].astype('category')
car['drivewheel']=car['drivewheel'].cat.codes
car=pd.get_dummies(car, columns=['drivewheel'])

# %%
car['enginelocation']=car['enginelocation'].astype('category')
car['enginelocation']=car['enginelocation'].cat.codes
car=pd.get_dummies(car, columns=['enginelocation'])

# %%
car['enginetype']=car['enginetype'].astype('category')
car['enginetype']=car['enginetype'].cat.codes
car=pd.get_dummies(car, columns=['enginetype'])

# %%
car['cylindernumber']=car['cylindernumber'].astype('category')
car['cylindernumber']=car['cylindernumber'].cat.codes
car=pd.get_dummies(car, columns=['cylindernumber'])

# %%
car['fuelsystem'] = car['fuelsystem'].astype('category')
car['fuelsystem'] =car['fuelsystem'].cat.codes
car=pd.get_dummies(car,columns=['fuelsystem'])

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 53 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   wheelbase         205 non-null    float64
#  2   carlength         205 non-null    float64
#  3   carwidth          205 non-null    float64
#  4   carheight         205 non-null    float64
#  5   curbweight        205 non-null    int64
#  6   enginesize        205 non-null    int64
#  7   boreratio         205 non-null    float64
#  8   stroke            205 non-null    float64
#  9   compressionratio  205 non-null    float64
#  10  horsepower        205 non-null    int64
#  11  peakrpm           205 non-null    int64
#  12  citympg           205 non-null    int64
#  13  highwaympg        205 non-null    int64
#  14  price             205 non-null    float64
#  15  fueltype_0        205 non-null    uint8
# ...

# %%
car.drop(['fueltype_0','aspiration_0','doornumber_0','carbody_0','drivewheel_0','enginelocation_0',
         'enginetype_0','cylindernumber_0','cylindernumber_0','fuelsystem_0'],axis=1,inplace=True)
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 44 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   wheelbase         205 non-null    float64
#  2   carlength         205 non-null    float64
#  3   carwidth          205 non-null    float64
#  4   carheight         205 non-null    float64
#  5   curbweight        205 non-null    int64
#  6   enginesize        205 non-null    int64
#  7   boreratio         205 non-null    float64
#  8   stroke            205 non-null    float64
#  9   compressionratio  205 non-null    float64
#  10  horsepower        205 non-null    int64
#  11  peakrpm           205 non-null    int64
#  12  citympg           205 non-null    int64
#  13  highwaympg        205 non-null    int64
#  14  price             205 non-null    float64
#  15  fueltype_1        205 non-null    uint8
# ...

# %%
car_uint8=car.select_dtypes(include=['uint8'])
car_uint8 = car_uint8.astype('int64')
car_uint8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fueltype_1        205 non-null    int64
#  1   aspiration_1      205 non-null    int64
#  2   doornumber_1      205 non-null    int64
#  3   carbody_1         205 non-null    int64
#  4   carbody_2         205 non-null    int64
#  5   carbody_3         205 non-null    int64
#  6   carbody_4         205 non-null    int64
#  7   drivewheel_1      205 non-null    int64
#  8   drivewheel_2      205 non-null    int64
#  9   enginelocation_1  205 non-null    int64
#  10  enginetype_1      205 non-null    int64
#  11  enginetype_2      205 non-null    int64
#  12  enginetype_3      205 non-null    int64
#  13  enginetype_4      205 non-null    int64
#  14  enginetype_5      205 non-null    int64
#  15  enginetype_6      205 non-null    int64
# ...

# %%
car = car.select_dtypes(exclude=['uint8'])
car = car.join(car_uint8)
car.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 car = car.select_dtypes(exclude=['uint8'])
# ----> 2 car = car.join(car_uint8)
#       3 car.info()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:9260, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort)
#    9106 def join(
#    9107     self,
#    9108     other: DataFrame | Series,
#    (...)
#    9113     sort: bool = False,
#    9114 ) -> DataFrame:
#    9115     """
#    9116     Join columns of another DataFrame.
#    9117
#    (...)
#    9258     5  K1  A5   B1
#    9259     """
# -> 9260     return self._join_compat(
#    9261         other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9262     )
#
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
car_col=car
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]

# %%
vif_data
# Out:
#              feature          VIF
# 0          symboling     3.732042
# 1          wheelbase    14.363094
# 2          carlength    15.432598
# 3           carwidth    11.715836
# 4          carheight     4.135332
# 5         curbweight    34.767193
# 6         enginesize    55.696388
# 7          boreratio     7.977914
# 8             stroke     3.877869
# 9   compressionratio   186.950683
# 10        horsepower    32.808465
# 11           peakrpm     3.973776
# 12           citympg    39.514017
# 13        highwaympg    36.823780
# 14             price    16.541545
# 15        fueltype_1  8619.662789
# 16      aspiration_1     5.026833
# 17      doornumber_1     3.585409
# 18         carbody_1     3.114746
# 19         carbody_2    14.907961
# 20         carbody_3    19.055712
# 21         carbody_4     9.926488
# 22      drivewheel_1    11.155425
# 23      drivewheel_2    14.447139
# 24  enginelocation_1     4.158079
# 25      enginetype_1     4.566523
# ...

# %%
car_col=car_col.drop(['fueltype_1'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature          VIF
# 0          symboling     5.383234
# 1          wheelbase  3892.634629
# 2          carlength  3100.394825
# 3           carwidth  6163.290354
# 4          carheight  1591.310593
# 5         curbweight   855.903274
# 6         enginesize   563.613467
# 7          boreratio  1219.049415
# 8             stroke   417.402969
# 9   compressionratio  1411.797961
# 10        horsepower   257.058445
# 11           peakrpm   411.798588
# 12           citympg   629.588898
# 13        highwaympg   758.366493
# 14             price    60.479784
# 15      aspiration_1     6.038101
# 16      doornumber_1     6.363091
# 17         carbody_1     3.160055
# 18         carbody_2    21.592341
# 19         carbody_3    34.265494
# 20         carbody_4    10.728213
# 21      drivewheel_1    26.184744
# 22      drivewheel_2    22.957987
# 23  enginelocation_1     4.213266
# 24      enginetype_1     4.583814
# 25      enginetype_2     6.303475
# ...

# %%
car_col=car_col.drop(['carwidth'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature          VIF
# 0          symboling     5.188466
# 1          wheelbase  3440.646545
# 2          carlength  2746.638572
# 3          carheight  1539.405454
# 4         curbweight   849.394878
# 5         enginesize   560.048491
# 6          boreratio  1197.994464
# 7             stroke   374.438048
# 8   compressionratio  1341.926887
# 9         horsepower   255.476883
# 10           peakrpm   385.138677
# 11           citympg   627.016458
# 12        highwaympg   744.107556
# 13             price    59.292663
# 14      aspiration_1     5.938639
# 15      doornumber_1     6.362950
# 16         carbody_1     3.065397
# 17         carbody_2    21.323641
# 18         carbody_3    32.457096
# 19         carbody_4     9.861729
# 20      drivewheel_1    26.184582
# 21      drivewheel_2    22.940546
# 22  enginelocation_1     4.076565
# 23      enginetype_1     4.495225
# 24      enginetype_2     6.090678
# 25      enginetype_3    26.268239
# ...

# %%
car_col=car_col.drop(['wheelbase'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature          VIF
# 0          symboling     4.482167
# 1          carlength  2185.088110
# 2          carheight  1193.305919
# 3         curbweight   848.070093
# 4         enginesize   530.762223
# 5          boreratio  1194.797876
# 6             stroke   369.968067
# 7   compressionratio  1314.691505
# 8         horsepower   242.937223
# 9            peakrpm   367.294758
# 10           citympg   619.407917
# 11        highwaympg   740.718780
# 12             price    58.694873
# 13      aspiration_1     5.648538
# 14      doornumber_1     6.362688
# 15         carbody_1     3.011567
# 16         carbody_2    19.945910
# 17         carbody_3    31.761086
# 18         carbody_4     9.826116
# 19      drivewheel_1    25.598129
# 20      drivewheel_2    21.955078
# 21  enginelocation_1     3.794026
# 22      enginetype_1     4.491813
# 23      enginetype_2     5.488081
# 24      enginetype_3    26.213289
# 25      enginetype_4     6.693601
# ...

# %%
car_col=car_col.drop(['carlength'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature          VIF
# 0          symboling     4.474586
# 1          carheight   916.750584
# 2         curbweight   695.016349
# 3         enginesize   530.126810
# 4          boreratio  1180.693423
# 5             stroke   369.146073
# 6   compressionratio  1218.616645
# 7         horsepower   242.415887
# 8            peakrpm   365.915600
# 9            citympg   612.638706
# 10        highwaympg   738.837599
# 11             price    58.691833
# 12      aspiration_1     5.628521
# 13      doornumber_1     6.359888
# 14         carbody_1     2.940914
# 15         carbody_2    19.159110
# 16         carbody_3    29.795608
# 17         carbody_4     9.511134
# 18      drivewheel_1    23.985456
# 19      drivewheel_2    21.636822
# 20  enginelocation_1     3.689030
# 21      enginetype_1     4.266382
# 22      enginetype_2     5.453025
# 23      enginetype_3    26.206853
# 24      enginetype_4     6.693515
# 25      enginetype_5     3.850759
# ...

# %%
car_col=car_col.drop(['boreratio'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature          VIF
# 0          symboling     4.444423
# 1          carheight   865.842366
# 2         curbweight   693.315111
# 3         enginesize   409.201405
# 4             stroke   369.139855
# 5   compressionratio  1184.898947
# 6         horsepower   235.810513
# 7            peakrpm   365.911351
# 8            citympg   606.195983
# 9         highwaympg   735.324024
# 10             price    58.324523
# 11      aspiration_1     5.621616
# 12      doornumber_1     6.352226
# 13         carbody_1     2.908553
# 14         carbody_2    19.051106
# 15         carbody_3    29.674534
# 16         carbody_4     9.457958
# 17      drivewheel_1    23.976358
# 18      drivewheel_2    20.666684
# 19  enginelocation_1     3.593820
# 20      enginetype_1     4.083199
# 21      enginetype_2     5.380126
# 22      enginetype_3    25.733010
# 23      enginetype_4     4.738025
# 24      enginetype_5     3.745559
# 25      enginetype_6          inf
# ...

# %%
car_col=car_col.drop(['compressionratio'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    4.030977
# 1          carheight  737.728464
# 2         curbweight  614.722616
# 3         enginesize  404.764370
# 4             stroke  367.942254
# 5         horsepower  224.470910
# 6            peakrpm  315.682883
# 7            citympg  572.552648
# 8         highwaympg  734.939979
# 9              price   57.770330
# 10      aspiration_1    5.422380
# 11      doornumber_1    6.248077
# 12         carbody_1    2.826524
# 13         carbody_2   19.013732
# 14         carbody_3   29.663012
# 15         carbody_4    9.409755
# 16      drivewheel_1   21.937201
# 17      drivewheel_2   17.949072
# 18  enginelocation_1    3.460659
# 19      enginetype_1    3.674638
# 20      enginetype_2    4.126451
# 21      enginetype_3   25.541249
# 22      enginetype_4    4.722919
# 23      enginetype_5    3.742034
# 24      enginetype_6         inf
# 25  cylindernumber_1   14.139948
# 26  cylindernumber_2  223.207089
# ...

# %%
ar_col=car_col.drop(['carheight'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    4.030977
# 1          carheight  737.728464
# 2         curbweight  614.722616
# 3         enginesize  404.764370
# 4             stroke  367.942254
# 5         horsepower  224.470910
# 6            peakrpm  315.682883
# 7            citympg  572.552648
# 8         highwaympg  734.939979
# 9              price   57.770330
# 10      aspiration_1    5.422380
# 11      doornumber_1    6.248077
# 12         carbody_1    2.826524
# 13         carbody_2   19.013732
# 14         carbody_3   29.663012
# 15         carbody_4    9.409755
# 16      drivewheel_1   21.937201
# 17      drivewheel_2   17.949072
# 18  enginelocation_1    3.460659
# 19      enginetype_1    3.674638
# 20      enginetype_2    4.126451
# 21      enginetype_3   25.541249
# 22      enginetype_4    4.722919
# 23      enginetype_5    3.742034
# 24      enginetype_6         inf
# 25  cylindernumber_1   14.139948
# 26  cylindernumber_2  223.207089
# ...

# %%
car_col=car_col.drop(['highwaympg'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.812341
# 1          carheight  737.633339
# 2         curbweight  612.760449
# 3         enginesize  402.880352
# 4             stroke  367.616039
# 5         horsepower  221.530895
# 6            peakrpm  313.440520
# 7            citympg  103.729052
# 8              price   57.192163
# 9       aspiration_1    5.129942
# 10      doornumber_1    6.155090
# 11         carbody_1    2.822178
# 12         carbody_2   18.924783
# 13         carbody_3   29.530406
# 14         carbody_4    9.407053
# 15      drivewheel_1   21.612491
# 16      drivewheel_2   17.909758
# 17  enginelocation_1    3.406049
# 18      enginetype_1    3.408367
# 19      enginetype_2    4.124694
# 20      enginetype_3   25.070566
# 21      enginetype_4    4.720191
# 22      enginetype_5    3.611638
# 23      enginetype_6         inf
# 24  cylindernumber_1   13.498369
# 25  cylindernumber_2  206.609201
# 26  cylindernumber_3   19.188261
# ...

# %%
car_col=car_col.drop(['curbweight'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.800298
# 1          carheight  580.616212
# 2         enginesize  322.408842
# 3             stroke  367.607317
# 4         horsepower  219.772739
# 5            peakrpm  313.174757
# 6            citympg   96.029157
# 7              price   54.042577
# 8       aspiration_1    5.073650
# 9       doornumber_1    5.927236
# 10         carbody_1    2.766095
# 11         carbody_2   18.885342
# 12         carbody_3   29.164319
# 13         carbody_4    9.401252
# 14      drivewheel_1   20.459028
# 15      drivewheel_2   17.798976
# 16  enginelocation_1    3.096604
# 17      enginetype_1    3.392965
# 18      enginetype_2    3.939817
# 19      enginetype_3   24.548031
# 20      enginetype_4    4.618671
# 21      enginetype_5    3.604791
# 22      enginetype_6         inf
# 23  cylindernumber_1   11.976663
# 24  cylindernumber_2  189.645648
# 25  cylindernumber_3   17.801481
# 26  cylindernumber_4    2.848516
# ...

# %%
car_col=car_col.drop(['stroke'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.798384
# 1          carheight  579.789147
# 2         enginesize  181.166176
# 3         horsepower  218.057179
# 4            peakrpm  285.822491
# 5            citympg   93.026105
# 6              price   46.560836
# 7       aspiration_1    4.830901
# 8       doornumber_1    5.921206
# 9          carbody_1    2.764346
# 10         carbody_2   18.874511
# 11         carbody_3   29.163212
# 12         carbody_4    9.400189
# 13      drivewheel_1   20.455409
# 14      drivewheel_2   17.309641
# 15  enginelocation_1    3.078642
# 16      enginetype_1    3.348768
# 17      enginetype_2    3.939495
# 18      enginetype_3   23.822509
# 19      enginetype_4    4.125224
# 20      enginetype_5    3.472369
# 21      enginetype_6         inf
# 22  cylindernumber_1   11.127102
# 23  cylindernumber_2  177.566877
# 24  cylindernumber_3   16.351768
# 25  cylindernumber_4    2.707964
# 26  cylindernumber_5    1.967129
# ...

# %%
car_col=car_col.drop(['peakrpm'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.725713
# 1          carheight  472.009319
# 2         enginesize  158.022784
# 3         horsepower  197.174362
# 4            citympg   86.201926
# 5              price   44.468897
# 6       aspiration_1    4.575852
# 7       doornumber_1    5.797882
# 8          carbody_1    2.751740
# 9          carbody_2   18.543116
# 10         carbody_3   27.998062
# 11         carbody_4    9.162710
# 12      drivewheel_1   20.065316
# 13      drivewheel_2   17.110541
# 14  enginelocation_1    3.004448
# 15      enginetype_1    3.345621
# 16      enginetype_2    3.833070
# 17      enginetype_3   23.021756
# 18      enginetype_4    3.934024
# 19      enginetype_5    3.378284
# 20      enginetype_6         inf
# 21  cylindernumber_1   10.179211
# 22  cylindernumber_2  167.772450
# 23  cylindernumber_3   15.974053
# 24  cylindernumber_4    2.692438
# 25  cylindernumber_5    1.961286
# 26  cylindernumber_6         inf
# ...

# %%
car_col=car_col.drop(['horsepower'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.703874
# 1          carheight  466.174089
# 2         enginesize  116.957943
# 3            citympg   80.183230
# 4              price   42.295522
# 5       aspiration_1    2.850996
# 6       doornumber_1    5.782761
# 7          carbody_1    2.716801
# 8          carbody_2   17.818767
# 9          carbody_3   27.109196
# 10         carbody_4    8.995655
# 11      drivewheel_1   19.992518
# 12      drivewheel_2   16.791604
# 13  enginelocation_1    2.365379
# 14      enginetype_1    1.530697
# 15      enginetype_2    3.115086
# 16      enginetype_3   20.333491
# 17      enginetype_4    3.684401
# 18      enginetype_5    3.356954
# 19      enginetype_6         inf
# 20  cylindernumber_1    9.123213
# 21  cylindernumber_2  150.064052
# 22  cylindernumber_3   13.017980
# 23  cylindernumber_4    2.480400
# 24  cylindernumber_5    1.565170
# 25  cylindernumber_6         inf
# 26      fuelsystem_1    7.322601
# ...

# %%
car_col=car_col.drop(['enginesize','enginetype_6','cylindernumber_6'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.601073
# 1          carheight  305.428448
# 2            citympg   77.180851
# 3              price   23.890245
# 4       aspiration_1    2.690959
# 5       doornumber_1    5.767040
# 6          carbody_1    2.560483
# 7          carbody_2   17.183432
# 8          carbody_3   26.730000
# 9          carbody_4    8.937071
# 10      drivewheel_1   19.287533
# 11      drivewheel_2   15.460575
# 12  enginelocation_1    2.230930
# 13      enginetype_1    1.340611
# 14      enginetype_2    3.025793
# 15      enginetype_3   19.873963
# 16      enginetype_4    3.683569
# 17      enginetype_5    2.709193
# 18  cylindernumber_1    6.219174
# 19  cylindernumber_2   94.461034
# 20  cylindernumber_3    8.268900
# 21  cylindernumber_4    2.094119
# 22  cylindernumber_5    1.292082
# 23      fuelsystem_1    7.280059
# 24      fuelsystem_2    2.798429
# 25      fuelsystem_3    4.326407
# 26      fuelsystem_4    1.223563
# ...

# %%
ar_col=car_col.drop(['cylindernumber_2'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.601073
# 1          carheight  305.428448
# 2            citympg   77.180851
# 3              price   23.890245
# 4       aspiration_1    2.690959
# 5       doornumber_1    5.767040
# 6          carbody_1    2.560483
# 7          carbody_2   17.183432
# 8          carbody_3   26.730000
# 9          carbody_4    8.937071
# 10      drivewheel_1   19.287533
# 11      drivewheel_2   15.460575
# 12  enginelocation_1    2.230930
# 13      enginetype_1    1.340611
# 14      enginetype_2    3.025793
# 15      enginetype_3   19.873963
# 16      enginetype_4    3.683569
# 17      enginetype_5    2.709193
# 18  cylindernumber_1    6.219174
# 19  cylindernumber_2   94.461034
# 20  cylindernumber_3    8.268900
# 21  cylindernumber_4    2.094119
# 22  cylindernumber_5    1.292082
# 23      fuelsystem_1    7.280059
# 24      fuelsystem_2    2.798429
# 25      fuelsystem_3    4.326407
# 26      fuelsystem_4    1.223563
# ...

# %%
car_col=car_col.drop(['citympg'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.601063
# 1          carheight  244.273518
# 2              price   21.881082
# 3       aspiration_1    2.574179
# 4       doornumber_1    5.585353
# 5          carbody_1    2.560035
# 6          carbody_2   17.146271
# 7          carbody_3   26.627831
# 8          carbody_4    8.932852
# 9       drivewheel_1   18.585339
# 10      drivewheel_2   15.295898
# 11  enginelocation_1    2.223233
# 12      enginetype_1    1.334897
# 13      enginetype_2    2.974152
# 14      enginetype_3   19.736294
# 15      enginetype_4    3.669378
# 16      enginetype_5    2.708260
# 17  cylindernumber_1    6.207320
# 18  cylindernumber_2   93.585684
# 19  cylindernumber_3    8.258562
# 20  cylindernumber_4    1.817578
# 21  cylindernumber_5    1.291670
# 22      fuelsystem_1    7.278164
# 23      fuelsystem_2    2.739091
# 24      fuelsystem_3    3.951075
# 25      fuelsystem_4    1.193685
# 26      fuelsystem_5   12.583725
# ...

# %%
car_col=car_col.drop(['enginetype_3'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.504723
# 1          carheight  243.744236
# 2              price   21.319771
# 3       aspiration_1    2.535439
# 4       doornumber_1    5.564939
# 5          carbody_1    2.486560
# 6          carbody_2   16.812045
# 7          carbody_3   26.040115
# 8          carbody_4    8.828741
# 9       drivewheel_1   18.564162
# 10      drivewheel_2   15.074278
# 11  enginelocation_1    2.131026
# 12      enginetype_1    1.316086
# 13      enginetype_2    1.699622
# 14      enginetype_4    1.749998
# 15      enginetype_5    2.362203
# 16  cylindernumber_1    5.641700
# 17  cylindernumber_2   84.914542
# 18  cylindernumber_3    8.148166
# 19  cylindernumber_4    1.771138
# 20  cylindernumber_5    1.291557
# 21      fuelsystem_1    7.278119
# 22      fuelsystem_2    2.722396
# 23      fuelsystem_3    3.950672
# 24      fuelsystem_4    1.191628
# 25      fuelsystem_5   12.485397
# 26      fuelsystem_6    2.343507
# ...

# %%
car_col=car_col.drop(['drivewheel_1'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.497918
# 1          carheight  230.629311
# 2              price   21.246370
# 3       aspiration_1    2.468506
# 4       doornumber_1    5.562061
# 5          carbody_1    2.482254
# 6          carbody_2   16.740897
# 7          carbody_3   25.955397
# 8          carbody_4    8.825428
# 9       drivewheel_2    4.725209
# 10  enginelocation_1    2.077841
# 11      enginetype_1    1.312920
# 12      enginetype_2    1.697904
# 13      enginetype_4    1.481852
# 14      enginetype_5    2.347180
# 15  cylindernumber_1    5.638572
# 16  cylindernumber_2   83.615679
# 17  cylindernumber_3    8.071438
# 18  cylindernumber_4    1.759872
# 19  cylindernumber_5    1.290306
# 20      fuelsystem_1    7.277676
# 21      fuelsystem_2    2.706924
# 22      fuelsystem_3    3.932537
# 23      fuelsystem_4    1.189653
# 24      fuelsystem_5   12.483478
# 25      fuelsystem_6    2.326259
# 26      fuelsystem_7    1.162188

# %%
car_col=car_col.drop(['price'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature         VIF
# 0          symboling    3.497767
# 1          carheight  132.497277
# 2       aspiration_1    2.310508
# 3       doornumber_1    5.528413
# 4          carbody_1    2.459208
# 5          carbody_2   16.242431
# 6          carbody_3   25.427010
# 7          carbody_4    8.465125
# 8       drivewheel_2    3.980193
# 9   enginelocation_1    1.931167
# 10      enginetype_1    1.312397
# 11      enginetype_2    1.677877
# 12      enginetype_4    1.481819
# 13      enginetype_5    2.311925
# 14  cylindernumber_1    4.865820
# 15  cylindernumber_2   53.900674
# 16  cylindernumber_3    6.665274
# 17  cylindernumber_4    1.582888
# 18  cylindernumber_5    1.268164
# 19      fuelsystem_1    7.269822
# 20      fuelsystem_2    2.275609
# 21      fuelsystem_3    3.932369
# 22      fuelsystem_4    1.180417
# 23      fuelsystem_5   12.391416
# 24      fuelsystem_6    2.312175
# 25      fuelsystem_7    1.162144

# %%
car_col=car_col.drop(['cylindernumber_2'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature        VIF
# 0          symboling   3.497761
# 1          carheight  73.438593
# 2       aspiration_1   2.293372
# 3       doornumber_1   5.496987
# 4          carbody_1   2.458591
# 5          carbody_2  16.169423
# 6          carbody_3  25.387943
# 7          carbody_4   8.460915
# 8       drivewheel_2   3.732299
# 9   enginelocation_1   1.921265
# 10      enginetype_1   1.058317
# 11      enginetype_2   1.663217
# 12      enginetype_4   1.481777
# 13      enginetype_5   1.552878
# 14  cylindernumber_1   1.272289
# 15  cylindernumber_3   2.174266
# 16  cylindernumber_4   1.178159
# 17  cylindernumber_5   1.218223
# 18      fuelsystem_1   7.244642
# 19      fuelsystem_2   1.559593
# 20      fuelsystem_3   3.932278
# 21      fuelsystem_4   1.180335
# 22      fuelsystem_5  12.387677
# 23      fuelsystem_6   2.308215
# 24      fuelsystem_7   1.156427

# %%
car_col=car_col.drop(['carheight'],axis=1)
vif_data = pd.DataFrame()
vif_data["feature"] =car_col.columns
vif_data["VIF"]=[variance_inflation_factor(car_col.values, i)for i in range(len(car_col.columns))]
vif_data
# Out:
#              feature       VIF
# 0          symboling  3.463420
# 1       aspiration_1  2.284678
# 2       doornumber_1  5.164428
# 3          carbody_1  1.789532
# 4          carbody_2  5.994198
# 5          carbody_3  7.419384
# 6          carbody_4  2.849339
# 7       drivewheel_2  3.668470
# 8   enginelocation_1  1.839927
# 9       enginetype_1  1.049912
# 10      enginetype_2  1.661993
# 11      enginetype_4  1.480568
# 12      enginetype_5  1.536329
# 13  cylindernumber_1  1.271840
# 14  cylindernumber_3  2.076126
# 15  cylindernumber_4  1.178132
# 16  cylindernumber_5  1.178172
# 17      fuelsystem_1  5.798167
# 18      fuelsystem_2  1.550509
# 19      fuelsystem_3  3.259766
# 20      fuelsystem_4  1.169096
# 21      fuelsystem_5  9.541076
# 22      fuelsystem_6  2.185536
# 23      fuelsystem_7  1.149419

# %%
car_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   aspiration_1      205 non-null    int64
#  2   doornumber_1      205 non-null    int64
#  3   carbody_1         205 non-null    int64
#  4   carbody_2         205 non-null    int64
#  5   carbody_3         205 non-null    int64
#  6   carbody_4         205 non-null    int64
#  7   drivewheel_2      205 non-null    int64
#  8   enginelocation_1  205 non-null    int64
#  9   enginetype_1      205 non-null    int64
#  10  enginetype_2      205 non-null    int64
#  11  enginetype_4      205 non-null    int64
#  12  enginetype_5      205 non-null    int64
#  13  cylindernumber_1  205 non-null    int64
#  14  cylindernumber_3  205 non-null    int64
#  15  cylindernumber_4  205 non-null    int64
# ...

# %%
x_car = car_col
y_car = car['price']
x=car.drop(['price'],axis=1) 
y = car['price']

# %%
from sklearn.preprocessing import StandardScaler
sc_car=StandardScaler()
sc_x_car= sc_car.fit_transform(x_car)

sc=StandardScaler()
sc_x=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train_car,x_test_car,y_train_car,y_test_car=train_test_split(sc_x_car,y_car,test_size=0.20,random_state=401)

x_train,x_test,y_train,y_test=train_test_split(sc_x,y,test_size=0.80,random_state=401)

# %%
from sklearn.linear_model import LinearRegression
lr_car=LinearRegression()
lr_car.fit(x_train_car,y_train_car)
# Out:
# LinearRegression()

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr_car=lr_car.predict(x_test_car)

y_pred_lr=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test_car,y_pred_lr_car))
print('*'*20)
print(r2_score(y_test,y_pred_lr))
# Out:
# 0.6367240946327537
# ********************
# 0.1410297505251632

# %%
from sklearn.metrics import mean_squared_error
mse_lr_car=mean_squared_error(y_test_car,y_pred_lr_car)
mse_lr=mean_squared_error(y_test,y_pred_lr)
print('Mean squared error without feature selection: {}'.format(np.round(mse_lr_car,2)))
print('Mean squared error with feature selection: {}'.format(np.round(mse_lr,2)))
# Out:
# Mean squared error without feature selection: 15627055.65
# Mean squared error with feature selection: 51798938.94

# %%
from statsmodels.regression.linear_model import OLS
import statsmodels.regression.linear_model as sf
lr_model_car=sf.OLS(endog=y_train_car,exog=x_train_car).fit()
lr_model_car.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.254
# Model:                            OLS   Adj. R-squared (uncentered):              0.126
# Method:                 Least Squares   F-statistic:                              1.984
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):                     0.00746
# Time:                        22:29:18   Log-Likelihood:                         -1795.2
# No. Observations:                 164   AIC:                                      3638.
# Df Residuals:                     140   BIC:                                      3713.
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
lr_model=sf.OLS(endog=y_train,exog=x_train).fit()
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     104.6
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):           2.89e-05
# Time:                        22:34:24   Log-Likelihood:                -294.23
# No. Observations:                  41   AIC:                             660.5
# Df Residuals:                       5   BIC:                             722.1
# Df Model:                          35
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1           759.2639    574.455      1.322      0.244    -717.419    2235.946
# ...

# %%
from scipy import stats
sns.distplot(lr_model_car.resid,fit=stats.norm)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.boxplot(lr_model_car.resid,showmeans=True)
# Out:
# <AxesSubplot:>

# %%
Y_max_car=y_car.max()
Y_min_car= y_car.min()
ax = sns.scatterplot(lr_model_car.fittedvalues,y_car)
ax.set(ylim=(Y_min_car,Y_max_car))
ax.set(xlim=(Y_min_car,Y_max_car))
ax.set_xlabel("Predicted value of Strength")
ax.set_ylabel("Observed value of Strength")
X_ref_car=Y_ref_car= np.linspace(Y_min_car,Y_max_car,100)
plt.plot(X_ref_car,Y_ref_car,color='red',linewidth=1)
plt.show()

# %%
from scipy import stats
sns.distplot(lr_model.resid,fit=stats.norm)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
Y_max = y.max()
Y_min = y.min()
ax = sns.scatterplot(lr_model.fittedvalues, y)
ax.set(ylim=(Y_min, Y_max))
ax.set(xlim=(Y_min, Y_max))
ax.set_xlabel("Predicted value of Strength")
ax.set_ylabel("Observed value of Strength")
X_ref = Y_ref = np.linspace(Y_min, Y_max, 100)
plt.plot(X_ref, Y_ref, color='red', linewidth=1)
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt=dt.predict(x_test)

# %%
print(r2_score(y_test,y_pred_dt))
# Out:
# 0.779837694660458

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = rf.predict(x_test)

# %%
print(r2_score(y_test,y_pred_rf))
# Out:
# 0.8775702633956434

# %%
import tensorflow as tf
from tensorflow import keras

# %%
x_train,x_test,y_train,y_test=train_test_split(sc_x,y,test_size=0.20,random_state=500)

# %%
DNN=tf.keras.models.Sequential()
DNN.add(tf.keras.layers.Dense(units=20,activation='relu'))
DNN.add(tf.keras.layers.Dense(units=20,activation='relu'))
DNN.add(tf.keras.layers.Dense(units=1))
DNN.compile(optimizer='adam',loss='mean_squared_error')
DNN.fit(x_train,y_train,batch_size=32,epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 3ms/step - loss: 233392096.0000
# Epoch 2/500
# 6/6 [==============================] - 0s 3ms/step - loss: 233383312.0000
# Epoch 3/500
# 6/6 [==============================] - 0s 3ms/step - loss: 233375072.0000
# Epoch 4/500
# 6/6 [==============================] - 0s 2ms/step - loss: 233366448.0000
# Epoch 5/500
# 6/6 [==============================] - 0s 2ms/step - loss: 233356688.0000
# Epoch 6/500
# 6/6 [==============================] - 0s 2ms/step - loss: 233346944.0000
# Epoch 7/500
# 6/6 [==============================] - 0s 1ms/step - loss: 233335584.0000
# Epoch 8/500
# 6/6 [==============================] - 0s 2ms/step - loss: 233323472.0000
# Epoch 9/500
# 6/6 [==============================] - 0s 2ms/step - loss: 233310464.0000
# Epoch 10/500
# 6/6 [==============================] - 0s 2ms/step - loss: 233295568.0000
# Epoch 11/500
# 6/6 [==============================] - 0s 2ms/step - loss: 233280288.0000
# ...

# %%
y_pred_DNN=DNN.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 0s/step

# %%
print(r2_score(y_test,y_pred_DNN))
# Out:
# 0.6430531288383665
